# %%
#https://github.com/fblamanna/TheConcertsTracker/blob/master/TheSetlistsTracker.py
#https://github.com/fblamanna/TheConcertsTracker/blob/master/TheConcertsTracker.py
#https://api.setlist.fm/docs/1.0/index.html
#https://github.com/topics/setlist-fm?l=python
#https://www.programmableweb.com/sample-source-code/setlist.fm-python-sample-code-mike-mattozzi

import requests
import csv
import sys
import math
import json
import pandas as pd
import numpy as np

# Call Setlist.fm API

# Total Number of Pages needed to load
totalshows = int(data['total'])
pages = int(math.ceil(totalshows/20))
show_maindf=list()
for page in range(1, 2):
  url = 'https://api.setlist.fm/rest/1.0/artist/' + '65f4f0c5-ef9e-490c-aee3-909e7ae6b2ab' + '/setlists?p=' + str(page)
  headers = {'Accept': 'application/json', 'x-api-key': '7bfaa44b-e419-49ec-925e-371072276c2f'
  }
  r = requests.get(url, headers=headers)
  data=r.json()
  
  for k in range(0,len(data['setlist'])):
    date = data['setlist'][k]['eventDate']
    tour = data['setlist'][k]['tour']['name']
    city = data['setlist'][k]['venue']['city']['name']

    country = data['setlist'][k]['venue']['city']['country']['name']

    header=city+', '+country+', '+date
    
    main_show=list()
    encore=list()
    main_show.append(header)
          
    try:
      for n_songs in range (0, len(data['setlist'][k]['sets']['set'][0]['song'])):
        main_show.append(data['setlist'][k]['sets']['set'][0]['song'][n_songs]['name'])

      for n_encore in range (0, (len(data['setlist'][k]['sets']['set'][1]['song']))):
        main_show.append(data['setlist'][k]['sets']['set'][1]['song'][n_encore]['name'])
      
       
      show_maindf.append(main_show)
    except:
      continue

# %%
show_maindf=np.array(show_maindf)
show_maindf=show_maindf.T
show_maindf
dftest=pd.DataFrame(show_maindf)
dftest.columns = dftest.iloc[0]
dftest=dftest.drop([0])
dftest
# Out:
# 0  Kansas City, United States, 06-03-2019 Wichita, United States, 04-03-2019  \
# 1                     The Ecstasy of Gold                The Ecstasy of Gold
# 2                         Hardwired Intro                    Hardwired Intro
# 3                               Hardwired                          Hardwired
# 4                            Atlas, Rise!                       Atlas, Rise!
# 5                          Seek & Destroy                     Seek & Destroy
# 6                      The Shortest Straw                  Through the Never
# 7                          The Unforgiven                     The Unforgiven
# 8                     Now That We're Dead                Now That We're Dead
# 9                          Creeping Death                     Creeping Death
# 10                For Whom the Bell Tolls            For Whom the Bell Tolls
# 11              Welcome Home (Sanitarium)                 Here Comes Revenge
# ...

# %%
dftest.mode(axis=1)
# Out:
#                             0                   1                  2
# 1         The Ecstasy of Gold                 NaN                NaN
# 2             Hardwired Intro                 NaN                NaN
# 3                   Hardwired                 NaN                NaN
# 4                Atlas, Rise!                 NaN                NaN
# 5              Seek & Destroy                 NaN                NaN
# 6            Holier Than Thou  Ride the Lightning  Through the Never
# 7              The Unforgiven                 NaN                NaN
# 8         Now That We're Dead                 NaN                NaN
# 9              Creeping Death                 NaN                NaN
# 10    For Whom the Bell Tolls                 NaN                NaN
# 11  Welcome Home (Sanitarium)                 NaN                NaN
# 12             Hit the Lights                 NaN                NaN
# 13                       Fuel                 NaN                NaN
# ...

# %%
#por informaçao adicional

c = data['setlist'][1]['sets']['set']
len(c)
main_show=list()
encore=list()
if (len(c)>1):
  #Means that the show has an encore
  for n_songs in range (0, len(data['setlist'][1]['sets']['set'][0]['song'])):
    main_show.append(data['setlist'][1]['sets']['set'][0]['song'][n_songs]['name'])
    
  for n_encore in range (0, (len(data['setlist'][1]['sets']['set'][1]['song']))):
    encore.append(data['setlist'][1]['sets']['set'][1]['song'][n_encore]['name'])

df_main=pd.DataFrame(main_show)
df_encore=pd.DataFrame(encore)

df_show=pd.concat([df_main, df_encore])
df_show.columns=[header]
df_show
# Out:
#    Wichita, United States, 04-03-2019
# 0                 The Ecstasy of Gold
# 1                     Hardwired Intro
# 2                           Hardwired
# 3                        Atlas, Rise!
# 4                      Seek & Destroy
# 5                  The Shortest Straw
# 6                      The Unforgiven
# 7                 Now That We're Dead
# 8                      Creeping Death
# 9             For Whom the Bell Tolls
# 10          Welcome Home (Sanitarium)
# 11                  The Four Horsemen
# 12                               Fuel
# 13                    Moth Into Flame
# 14                       Sad but True
# 15                                One
# 16                  Master of Puppets
# 0                   Spit Out the Bone
# 1                Nothing Else Matters
# 2                       Enter Sandman

# %%
date=data['setlist'][2]['eventDate']

city=data['setlist'][2]['venue']['city']['name']

country = data['setlist'][2]['venue']['city']['country']['name']
country
# Out:
# 'United States'

# %%
print(
				                # Event ID
				                data['setlist'][1]['id'],
				                # Artist
				                data['setlist'][1]['artist']['name'],
				                # Eventdate
				                data['setlist'][1]['eventDate'],
				                # TourName
				                c,
				                # Venue
				                data['setlist'][1]['venue'].get('name'),
				                # Venue ID
				                data['setlist'][1]['venue'].get('id'),
				                # City
				                data['setlist'][1]['venue']['city'].get('name'),
				                # City ID
				                data['setlist'][1]['venue']['city'].get('id'),
				                # City Latitude
				                float(data['setlist'][1]['venue']['city']['coords'].get('lat')),
				                # City Longitude
				                float(data['setlist'][1]['venue']['city']['coords'].get('long')),
				                # State
				                data['setlist'][1]['venue']['city'].get('state'),
				                # State Code
				                data['setlist'][1]['venue']['city'].get('stateCode'),
				                # Country
				                data['setlist'][1]['venue']['city']['country'].get('name'),
				                # Country Code
				                data['setlist'][1]['venue']['city']['country'].get('code')
				                )
# Out:
# 1b92d53c Metallica 06-03-2019 Worldwired Tour Sprint Center 5bd61fa0 Kansas City 4393217 39.0997266 -94.5785667 Missouri MO United States US
